# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\lenovo\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn) (3.6.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

file_path = "employee_promotion_sampled.csv" 
df = pd.read_csv( "employee_promotion_sampled.csv" )
df
# Out:
#        employee_id         department     region         education gender  \
# 0            67220  Sales & Marketing   region_2        Bachelor's      m
# 1              992        Procurement   region_2        Bachelor's      f
# 2            27855                 HR  region_22  Master's & above      m
# 3            16879  Sales & Marketing  region_16               NaN      m
# 4            61804         Technology   region_2  Master's & above      m
# ...            ...                ...        ...               ...    ...
# 16437        32935         Operations   region_2        Bachelor's      m
# 16438        56296  Sales & Marketing  region_27        Bachelor's      f
# 16439        74628  Sales & Marketing   region_1  Master's & above      f
# 16440         3788  Sales & Marketing  region_16        Bachelor's      f
# 16441        11272        Procurement  region_20        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   57                   5.0
# 1                   other                1   31                   5.0
# 2                   other                1   37                   5.0
# 3                   other                1   23                   2.0
# 4                   other                1   43                   5.0
# ...                   ...              ...  ...                   ...
# 16437               other                1   44                   5.0
# 16438               other                1   29                   NaN
# 16439            sourcing                1   31                   1.0
# 16440            sourcing                1   38                   3.0
# 16441               other                1   40                   4.0
#
#        length_of_service  awards_won  avg_training_score  is_promoted
# 0                     18           0                52.0            0
# 1                      2           0                70.0            1
# 2                     10           0                47.0            0
# 3                      1           0                49.0            0
# 4                     12           0                77.0            1
# ...                  ...         ...                 ...          ...
# 16437                 15           0                58.0            0
# 16438                  1           0                50.0            0
# 16439                  2           0                48.0            0
# 16440                  6           0                50.0            0
# 16441                  6           0                69.0            0
#
# [16442 rows x 13 columns]

# %%
print("Dataset Overview:")
print(df.head())
# Out:
# Dataset Overview:
#    employee_id         department     region         education gender  \
# 0        67220  Sales & Marketing   region_2        Bachelor's      m
# 1          992        Procurement   region_2        Bachelor's      f
# 2        27855                 HR  region_22  Master's & above      m
# 3        16879  Sales & Marketing  region_16               NaN      m
# 4        61804         Technology   region_2  Master's & above      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   57                   5.0
# 1               other                1   31                   5.0
# 2               other                1   37                   5.0
# 3               other                1   23                   2.0
# 4               other                1   43                   5.0
#
#    length_of_service  awards_won  avg_training_score  is_promoted
# 0                 18           0                52.0            0
# 1                  2           0                70.0            1
# 2                 10           0                47.0            0
# 3                  1           0                49.0            0
# 4                 12           0                77.0            1

# %%
sample_df, _ = train_test_split(df, test_size=0.7, stratify=df["department"], random_state=42)
print("\nSampled Data Distribution:\n", sample_df["department"].value_counts(normalize=True))
print("\nOriginal Data Distribution:\n", df["department"].value_counts(normalize=True))
# Out:
# Sampled Data Distribution:
#  department
# Sales & Marketing    0.307178
# Operations           0.207015
# Procurement          0.130170
# Technology           0.130170
# Analytics            0.097729
# Finance              0.046229
# HR                   0.044201
# Legal                0.019059
# R&D                  0.018248
# Name: proportion, dtype: float64
#
# Original Data Distribution:
#  department
# Sales & Marketing    0.307262
# Operations           0.207031
# Procurement          0.130215
# Technology           0.130215
# Analytics            0.097677
# Finance              0.046284
# HR                   0.044094
# Legal                0.018976
# R&D                  0.018246
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
df["department"].value_counts().plot(kind="bar", color="blue", alpha=0.7)
plt.title("Original Department Distribution")
plt.xlabel("Department")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.subplot(1, 2, 2)
sample_df["department"].value_counts().plot(kind="bar", color="green", alpha=0.7)
plt.title("Sampled Department Distribution (30%)")
plt.xlabel("Department")
plt.ylabel("Count")

plt.tight_layout()
plt.show()
